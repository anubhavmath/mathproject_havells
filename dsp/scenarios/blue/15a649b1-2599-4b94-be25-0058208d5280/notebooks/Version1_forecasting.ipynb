# %%
# !pip install statsmodels
# !pip install pmdarima
# Out:
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.7/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: pandas>=0.21 in /opt/conda/lib/python3.7/site-packages (from statsmodels) (1.3.0)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.7/site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: scipy>=1.1 in /opt/conda/lib/python3.7/site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.21->statsmodels) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from patsy>=0.5->statsmodels) (1.11.0)
# Requirement already satisfied: pmdarima in /opt/conda/lib/python3.7/site-packages (1.8.2)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.7.1)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: numpy~=1.19.0 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (0.24.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (41.0.1)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.7/site-packages (from pmdarima) (1.3.0)
# Requirement already satisfied: patsy>=0.5 in /opt/conda/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from patsy>=0.5->statsmodels!=0.12.0,>=0.11->pmdarima) (1.11.0)

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import os
import warnings
warnings.filterwarnings(action='ignore')
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
from hdfs import InsecureClient
client = InsecureClient('http://datalake:50070')

client.status("/")
with client.read('/shared/havells_trail/raw/TSA.csv', encoding = 'utf-8') as reader:
    df = pd.read_csv(reader, sep=",",parse_dates=['calendar_year_month'],index_col='calendar_year_month')

# %%
df.head()
# Out:
#                      qty_final
# calendar_year_month
# 2016-01-01              5945.0
# 2016-02-01              5685.0
# 2016-03-01              5690.0
# 2016-04-01              7344.0
# 2016-05-01              9419.0

# %%
df.tail()
# Out:
#                      qty_final
# calendar_year_month
# 2019-08-01             12170.0
# 2019-09-01             13905.0
# 2019-10-01             14953.0
# 2019-11-01              8125.0
# 2019-12-01             11184.0

# %% [markdown]
# ## Plotting the dataframe

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,5)
df.plot()
plt.show()

# %%
## We can see the repaeted patterns i.e seasonality in the plot

# %% [markdown]
# ## Decomposing the timeSeries

# %%
df_add_decompose=seasonal_decompose(df,model='additive',period=1)  #additive decomposing

# %%
df_add_decompose.plot()
plt.show()

# %%
## Multiplicative Decomposing

# %%
df_multi_decompose=seasonal_decompose(df,model='multiplicative',period=1)

# %%
df_multi_decompose.plot()
plt.show()

# %%
##applying log transformation

# %%
df_log=df.copy()
df_log['qty_final']=np.log(df)

# %%
df_log.qty_final
# Out:
# calendar_year_month
# 2016-01-01    8.690306
# 2016-02-01    8.645586
# 2016-03-01    8.646466
# 2016-04-01    8.901639
# 2016-05-01    9.150484
#                 ...
# 2019-08-01    9.406729
# 2019-09-01    9.540004
# 2019-10-01    9.612667
# 2019-11-01    9.002701
# 2019-12-01    9.322239
# Name: qty_final, Length: 480, dtype: float64

# %%
df_log.plot()
plt.show()

# %%
plt.subplot(2,1,1)
plt.title('original time series')
plt.plot(df)
plt.subplot(2,1,2)
plt.title('log_transformed time series')
plt.plot(df_log)
plt.tight_layout()

# %%
##Splitting the data into train and test

# %%
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing,Holt
from IPython.display import display
from sklearn.metrics import mean_squared_error
import statsmodels.tools.eval_measures as em

# %%
## SPLITTING THE DATA INTO TRAIN AND TEST

# %%
train=df[df.index<='2018-01-01']
test=df[df.index>'2018-12-01']

# %%
model_ses=SimpleExpSmoothing(train)
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:587: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
model_ses_autofit=model_ses.fit(optimized=True)

# %%
model_ses_autofit.params
# Out:
# {'smoothing_level': 0.32732558139534884,
#  'smoothing_trend': nan,
#  'smoothing_seasonal': nan,
#  'damping_trend': nan,
#  'initial_level': 5945.0,
#  'initial_trend': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
ses_predict=model_ses_autofit.forecast(len(test))
ses_predict
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 250    22360.26313
# 251    22360.26313
# 252    22360.26313
# 253    22360.26313
# 254    22360.26313
#           ...
# 365    22360.26313
# 366    22360.26313
# 367    22360.26313
# 368    22360.26313
# 369    22360.26313
# Length: 120, dtype: float64

# %% [markdown]
# ## plotting

# %%
plt.plot(train,label='train')
plt.plot(test,label='test')
plt.plot(ses_predict,label='alpha=0.327')
plt.grid()
plt.title('alpha=0.327 predictions')
# Out:
# Text(0.5, 1.0, 'alpha=0.327 predictions')

# %%
## Calculating the mean squared error

# %%
print('mse',mean_squared_error(test.values,ses_predict.values,squared=False))
# Out:
# mse 20077.362895692688

# %% [markdown]
# ## Holt method

# %%
model_holt=Holt(train)
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:587: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)

# %%
model_holt=model_holt.fit()
model_holt.params
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/holtwinters/model.py:922: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# {'smoothing_level': 0.3114285714285714,
#  'smoothing_trend': 0.013540372670807451,
#  'smoothing_seasonal': nan,
#  'damping_trend': nan,
#  'initial_level': 5945.0,
#  'initial_trend': -260.0,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
holt_predict=model_holt.forecast(len(test))
holt_predict
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 250    23357.328134
# 251    23533.215328
# 252    23709.102522
# 253    23884.989716
# 254    24060.876910
#            ...
# 365    43584.355446
# 366    43760.242640
# 367    43936.129834
# 368    44112.017028
# 369    44287.904222
# Length: 120, dtype: float64

# %%
plt.plot(train,label='train')
plt.plot(test,label='test')
plt.plot(ses_predict,label='alpha=0.327')
plt.plot(holt_predict,label='alpha=0.311,beta=0.013')
plt.grid()
plt.title('predictions')
# Out:
# Text(0.5, 1.0, 'predictions')

# %%
print('mse',mean_squared_error(test.values,holt_predict.values,squared=False))
# Out:
# mse 31090.953819709324

# %% [markdown]
# ## Holt_winters

# %%
model_tes=ExponentialSmoothing(train,trend='additive',seasonal='additive',seasonal_periods=12)
model_tes=model_tes.fit()
model_tes.params
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:587: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/holtwinters/model.py:922: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# {'smoothing_level': 0.11107142857142857,
#  'smoothing_trend': 0.04936507936507936,
#  'smoothing_seasonal': 0.5596957671957672,
#  'damping_trend': nan,
#  'initial_level': 3242.6666666666665,
#  'initial_trend': -45.111111111111114,
#  'initial_seasons': array([2702.33333333, 2442.33333333, 2447.33333333, 4101.33333333,
#         6176.33333333, 2449.33333333, 4440.33333333, 4605.33333333,
#         1844.33333333, 3422.33333333, 5509.33333333, 2916.33333333]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
tes_predict=model_tes.forecast(len(test))
tes_predict
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 250    27705.928536
# 251    27101.672135
# 252    22219.032977
# 253    28093.948450
# 254    45159.544699
#            ...
# 365    73571.949276
# 366    68035.082915
# 367    64841.984434
# 368    60743.715435
# 369    73403.272301
# Length: 120, dtype: float64

# %%
plt.plot(train,label='train')
plt.plot(test,label='test')
plt.plot(ses_predict,label='alpha=0.327')
plt.plot(holt_predict,label='alpha=0.311,beta=0.013')
plt.plot(tes_predict,label='alpha,beta,gamma')
plt.grid()
plt.title('predictions')
plt.show()

# %%
print('mse',mean_squared_error(test.values,tes_predict.values,squared=False))
# Out:
# mse 49459.54542404924

# %%
df.head()
# Out:
#                      qty_final
# calendar_year_month
# 2016-01-01              5945.0
# 2016-02-01              5685.0
# 2016-03-01              5690.0
# 2016-04-01              7344.0
# 2016-05-01              9419.0

# %%
from matplotlib import pyplot
model = ARIMA(df, order=(5,1,0))
model_fit = model.fit()
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
plt.show()
# density plot of residuals
residuals.plot(kind='kde')
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:587: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/conda/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:587: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   ' forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.qty_final   No. Observations:                  479
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -4643.477
# Method:                       css-mle   S.D. of innovations           3922.775
# Date:                Fri, 06 Aug 2021   AIC                           9300.953
# Time:                        12:38:54   BIC                           9330.155
# Sample:                             1   HQIC                          9312.433
#
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 9.6433     91.174      0.106      0.916    -169.055     188.342
# ar.L1.D.qty_final    -0.4199      0.046     -9.204      0.000      -0.509      -0.330
# ar.L2.D.qty_final    -0.0368      0.047     -0.779      0.436      -0.129       0.056
# ar.L3.D.qty_final    -0.1502      0.047     -3.218      0.001      -0.242      -0.059
# ar.L4.D.qty_final    -0.3267      0.047     -6.929      0.000      -0.419      -0.234
# ar.L5.D.qty_final    -0.0373      0.046     -0.817      0.414      -0.127       0.052
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.8346           -1.0621j            1.3508           -0.1440
# AR.2            0.8346           +1.0621j            1.3508            0.1440
# AR.3           -1.0779           -0.7837j            1.3327           -0.3999
# AR.4           -1.0779           +0.7837j            1.3327            0.3999
# AR.5           -8.2755           -0.0000j            8.2755           -0.5000
# -----------------------------------------------------------------------------
#                   0
# count    479.000000
# mean       1.497805
# std     3927.147806
# min   -14453.506455
# 25%     -139.291501
# 50%      -23.650845
# 75%       45.381556
# max    31990.642966

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
fig,ax = plt.subplots(2,1)
fig = sm.graphics.tsa.plot_acf(train, lags=50, ax=ax[0])
fig = sm.graphics.tsa.plot_pacf(train, lags=50, ax=ax[1])
plt.show()

# %%
import pickle
pickle.dump(model_fit, open("Forecast_lm.pickle.dat", "wb"))
